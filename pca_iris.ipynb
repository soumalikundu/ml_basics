# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# PCA (Principal Component Analysis) is a dimensionality reduction technique used in machine learning and statistics. It transforms a large set of correlated variables into a smaller set of uncorrelated variables called principal components, while preserving as much variance as possible.

# %% [markdown]
# ## How PCA workd
#
# 1. Standardization: Normalize the data so that all features have mean = 0 and variance = 1.
# 2. Compute Covariance Matrix: Find how features are correlated with each other.
# 3. Find Eigenvalues & Eigenvectors: These define the new axes (principal components).
# 5. Sort Eigenvectors: Based on their eigenvalues (importance of each component).
# 6. Select Top k Components: Retain only the most significant principal components.
# 7. Transform Data: Project the original data onto the selected principal components.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn import datasets
from sklearn.preprocessing import StandardScaler

# %%
iris = datasets.load_iris()
X = iris.data  
y = iris.target

# %%
# Standardize the data (PCA works better with normalized data)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply PCA (reduce to 2 dimensions for visualization)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette="viridis", s=100)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA on Iris Dataset")
plt.show()

# %% [markdown]
# ## uses of PCA
#
# 1. Dimensionality Reduction: Reduces the number of features while retaining the most important information.
# 2. Visualization: Helps in plotting high-dimensional data in 2D or 3D.
# 3. Noise Reduction: Removes less significant variations (useful in image processing).
# 4. Speed Up ML Models: Reduces computation time by lowering the number of features.
# 5. Feature Engineering: Identifies important patterns in data.

# %% [markdown]
# ## When Not to use PCA
#
# - If interpretability of features is important (since PCA transforms them).
# - When features are not correlated (PCA works best when features are highly correlated).
# - If you want to preserve scale-sensitive information (e.g., categorical data).
